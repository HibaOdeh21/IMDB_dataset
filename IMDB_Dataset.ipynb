# %%
import pandas as pd 
import matplotlib.pyplot as plt
imdb_path='imdb_top_1000.csv'
imdb_data=pd.read_csv(imdb_path)
print(imdb_data)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
imdb_data = imdb_data.dropna(axis=0)
print(imdb_data)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
imdb_data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
genre_counts=imdb_data['Genre'].value_counts()
g=genre_counts.idxmax()
print(genre_counts)
print("the most popular genre is : ",g)
# Out:
# Drama                         58
# Drama, Romance                26
# Comedy, Drama                 24
# Crime, Drama, Thriller        22
# Action, Adventure, Sci-Fi     21
#                               ..
# Crime, Film-Noir, Thriller     1
# Drama, Film-Noir, Romance      1
# Drama, History, Romance        1
# Adventure, Horror, Sci-Fi      1
# Comedy, Music, Musical         1
# Name: Genre, Length: 172, dtype: int64
# the most popular genre is :  Drama

# %%
counts=pd.DataFrame(genre_counts).reset_index()
counts.columns=['Genre','Count']
print(counts)
# Out:
#                           Genre  Count
# 0                         Drama     58
# 1                Drama, Romance     26
# 2                 Comedy, Drama     24
# 3        Crime, Drama, Thriller     22
# 4     Action, Adventure, Sci-Fi     21
# ..                          ...    ...
# 167  Crime, Film-Noir, Thriller      1
# 168   Drama, Film-Noir, Romance      1
# 169     Drama, History, Romance      1
# 170   Adventure, Horror, Sci-Fi      1
# 171      Comedy, Music, Musical      1
#
# [172 rows x 2 columns]

# %%
plt.figure(figsize=(100,20))
plt.bar(counts['Genre'],counts['Count'])
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Most Popular Genre of shows')
plt.xticks(rotation=90)
plt.show()

# %%
director_counts=imdb_data['Director'].value_counts()
director_counts_imdb=pd.DataFrame(director_counts).reset_index()
director_counts_imdb.columns=['Director','Count']
d=director_counts.idxmax()
print(director_counts_imdb)
print("the director with the most top-rated movies/TV shows is :",d)
# Out:
#              Director  Count
# 0    Alfred Hitchcock     14
# 1    Steven Spielberg     13
# 2      Hayao Miyazaki     11
# 3     Martin Scorsese     10
# 4      Akira Kurosawa     10
# ..                ...    ...
# 543    Neill Blomkamp      1
# 544   Tomas Alfredson      1
# 545      Duncan Jones      1
# 546   Jacques Audiard      1
# 547    George Stevens      1
#
# [548 rows x 2 columns]
# the director with the most top-rated movies/TV shows is : Alfred Hitchcock

# %%
plt.figure(figsize=(100,20))
plt.bar(director_counts_imdb['Director'],director_counts_imdb['Count'])
plt.xlabel('Director')
plt.ylabel('Count')
plt.title('Top Rated Movies/TV shows by Director')
plt.xticks(rotation=90)
plt.show()

# %%
#The dataset consists of information about the top-rated movies and TV shows, including columns such as Title, Genre, Director, and Rating.
#To prepare the dataset for analysis, we performed the following preprocessing steps:
#Removed unnecessary columns: We dropped columns such as Rank, Description, Runtime (Minutes), Votes, Revenue (Millions), and Metascore, as they were not relevant to our analysis.
#Handled missing values: We removed any rows with missing values from the dataset.
#Most Popular Genre
#To determine the most popular genre among the top-rated movies and TV shows, we analyzed the dataset and found the following result:
#The most popular genre is Drama

#To identify the director with the most top-rated movies/TV shows, we analyzed the dataset and found the following result:#
#The director with the most top-rated movies/TV shows is Alfred Hitchcock

#We created bar charts to visualize our findings
